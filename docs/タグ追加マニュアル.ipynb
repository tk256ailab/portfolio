# %% [markdown]
# # タグ追加・カスタマイズマニュアル
#
# このノートブックでは、ポートフォリオサイトのプロジェクトタグとブログカテゴリを追加・カスタマイズする方法を説明します。
#
# ## 📋 目次
#
# 1. [タグシステムの概要](#タグシステムの概要)
# 2. [プロジェクトタグの追加](#プロジェクトタグの追加)
# 3. [ブログカテゴリの追加](#ブログカテゴリの追加)
# 4. [タグの色のカスタマイズ](#タグの色のカスタマイズ)
# 5. [動作確認](#動作確認)

# %% [markdown]
# ## タグシステムの概要
#
# ### プロジェクトタグとブログカテゴリの違い
#
# | 項目 | プロジェクトタグ | ブログカテゴリ |
# |------|-----------------|----------------|
# | **目的** | 使用技術を表示 | 記事の分類 |
# | **複数設定** | ✅ 可能（複数のタグ） | ❌ 不可（1記事1カテゴリ） |
# | **フィルター機能** | ✅ あり | ✅ あり |
# | **自動生成** | ✅ タグボタンが自動生成 | ❌ HTMLで手動定義 |
# | **データ保存場所** | `data/projects.json` | `data/blogs.json` |
# | **表示場所** | Projectsページ | Blogsページ |
#
# ### 現在のタグとカテゴリ
#
# **プロジェクトタグ**（自由に追加可能）:
# - Python, JavaScript, React, Node.js, Three.js, WebGL, VRM, Animation
# - Machine Learning, Data Science, Kaggle, OpenAI API, FastAPI, AI
#
# **ブログカテゴリ**（固定、追加には編集が必要）:
# - `ai`: AI・機械学習
# - `web`: Web開発
# - `algorithm`: アルゴリズム
# - `self-developed`: 自作ツール
# - `blender`: Blender

# %% [markdown]
# ## プロジェクトタグの追加
#
# プロジェクトタグは**自動生成**されるため、JSONファイルに記述するだけで追加できます。
#
# ### 手順1: data/projects.json でタグを追加
#
# 新しいプロジェクトを追加する際、`tags` フィールドに任意のタグを記述します。

# %% [markdown]
# ### 例1: 新しいタグ「TypeScript」を追加
#
# ```json
# {
#   "id": 6,
#   "title": "新しいプロジェクト",
#   "titleEn": "New Project",
#   "description": "TypeScriptを使った開発プロジェクト",
#   "descriptionEn": "Development project using TypeScript",
#   "image": "assets/images/projects/new-project.png",
#   "github": "https://github.com/tk256ailab/new-project",
#   "demo": "https://demo.com",
#   "tags": ["TypeScript", "React", "Node.js"],
#   "category": "web"
# }
# ```
#
# これだけで、Projectsページに「TypeScript」のフィルターボタンが**自動的に追加**されます。

# %% [markdown]
# ### 例2: 複数の新しいタグを追加
#
# ```json
# {
#   "id": 7,
#   "title": "モバイルアプリ開発",
#   "titleEn": "Mobile App Development",
#   "description": "React Nativeを使ったモバイルアプリ開発",
#   "descriptionEn": "Mobile app development using React Native",
#   "image": "assets/images/projects/mobile-app.png",
#   "github": "https://github.com/tk256ailab/mobile-app",
#   "demo": null,
#   "tags": ["React Native", "TypeScript", "Firebase", "iOS", "Android"],
#   "category": "web"
# }
# ```
#
# この場合、以下のタグフィルターが自動追加されます：
# - React Native
# - TypeScript（既に存在する場合は追加されない）
# - Firebase
# - iOS
# - Android

# %% [markdown]
# ### タグの命名規則
#
# ✅ **推奨**:
# - 大文字で始める: `Python`, `JavaScript`, `React`
# - 正式名称を使用: `Node.js`, `Three.js`, `OpenAI API`
# - 略語は大文字: `AI`, `ML`, `API`
#
# ❌ **非推奨**:
# - 小文字のみ: `python`, `javascript`
# - 不統一: `nodejs` と `Node.js` を混在
# - 長すぎるタグ: `Very Long Technology Name Here`
#
# ### タグの自動生成の仕組み
#
# `assets/js/filters.js` の `ProjectFilter` クラスが、全プロジェクトの `tags` フィールドを収集して、重複を除いた一覧をフィルターボタンとして生成します。
#
# ```javascript
# generateTagFilters() {
#     const allTags = new Set();
#
#     this.allProjects.forEach(project => {
#         project.tags.forEach(tag => {
#             allTags.add(tag.toLowerCase());
#         });
#     });
#
#     // フィルターボタンを自動生成
#     ...
# }
# ```

# %% [markdown]
# ## ブログカテゴリの追加
#
# ブログカテゴリは**固定**で、新しいカテゴリを追加するには複数のファイルを編集する必要があります。
#
# ### 手順1: pages/blogs.html のフィルターボタンを追加
#
# 新しいカテゴリ「Data Science」を追加する例：

# %% [markdown]
# #### 編集箇所: pages/blogs.html
#
# **編集前**:
#
# ```html
# <div class="blog-filters">
#     <button class="filter-btn active" data-category="all">
#         <span class="jp">すべて</span>
#         <span class="en" style="display: none;">All</span>
#     </button>
#     <button class="filter-btn" data-category="ai">
#         <span class="jp">AI・機械学習</span>
#         <span class="en" style="display: none;">AI・ML</span>
#     </button>
#     <button class="filter-btn" data-category="web">
#         <span class="jp">Web開発</span>
#         <span class="en" style="display: none;">Web Dev</span>
#     </button>
#     <button class="filter-btn" data-category="algorithm">
#         <span class="jp">アルゴリズム</span>
#         <span class="en" style="display: none;">Algorithm</span>
#     </button>
#     <button class="filter-btn" data-category="self-developed">
#         <span class="jp">自作ツール</span>
#         <span class="en" style="display: none;">Self-developed tool</span>
#     </button>
#     <button class="filter-btn" data-category="blender">
#         <span class="jp">Blender</span>
#         <span class="en" style="display: none;">Blender</span>
#     </button>
# </div>
# ```

# %% [markdown]
# **編集後** (新しいカテゴリ「Data Science」を追加):
#
# ```html
# <div class="blog-filters">
#     <button class="filter-btn active" data-category="all">
#         <span class="jp">すべて</span>
#         <span class="en" style="display: none;">All</span>
#     </button>
#     <button class="filter-btn" data-category="ai">
#         <span class="jp">AI・機械学習</span>
#         <span class="en" style="display: none;">AI・ML</span>
#     </button>
#     <button class="filter-btn" data-category="web">
#         <span class="jp">Web開発</span>
#         <span class="en" style="display: none;">Web Dev</span>
#     </button>
#     <button class="filter-btn" data-category="data-science">
#         <span class="jp">データサイエンス</span>
#         <span class="en" style="display: none;">Data Science</span>
#     </button>
#     <button class="filter-btn" data-category="algorithm">
#         <span class="jp">アルゴリズム</span>
#         <span class="en" style="display: none;">Algorithm</span>
#     </button>
#     <button class="filter-btn" data-category="self-developed">
#         <span class="jp">自作ツール</span>
#         <span class="en" style="display: none;">Self-developed tool</span>
#     </button>
#     <button class="filter-btn" data-category="blender">
#         <span class="jp">Blender</span>
#         <span class="en" style="display: none;">Blender</span>
#     </button>
# </div>
# ```
#
# **重要**: `data-category="data-science"` の値がカテゴリIDになります。

# %% [markdown]
# ### 手順2: assets/js/filters.js のカテゴリマップを更新
#
# `BlogFilter` クラス内の `getCategoryNameJP()` と `getCategoryNameEN()` メソッドにカテゴリを追加します。

# %% [markdown]
# #### 編集箇所: assets/js/filters.js
#
# **編集前**:
#
# ```javascript
# getCategoryNameJP(category) {
#     const categoryMap = {
#         'ai': 'AI・機械学習',
#         'web': 'Web開発',
#         'algorithm': 'アルゴリズム',
#         'self-developed': '自作ツール',
#         'blender': 'Blender'
#     };
#     return categoryMap[category] || category;
# }
#
# getCategoryNameEN(category) {
#     const categoryMap = {
#         'ai': 'AI・ML',
#         'web': 'Web Dev',
#         'algorithm': 'Algorithm',
#         'self-developed': 'Self-developed tool',
#         'blender': 'Blender'
#     };
#     return categoryMap[category] || category;
# }
# ```

# %% [markdown]
# **編集後** (新しいカテゴリを追加):
#
# ```javascript
# getCategoryNameJP(category) {
#     const categoryMap = {
#         'ai': 'AI・機械学習',
#         'web': 'Web開発',
#         'data-science': 'データサイエンス',
#         'algorithm': 'アルゴリズム',
#         'self-developed': '自作ツール',
#         'blender': 'Blender'
#     };
#     return categoryMap[category] || category;
# }
#
# getCategoryNameEN(category) {
#     const categoryMap = {
#         'ai': 'AI・ML',
#         'web': 'Web Dev',
#         'data-science': 'Data Science',
#         'algorithm': 'Algorithm',
#         'self-developed': 'Self-developed tool',
#         'blender': 'Blender'
#     };
#     return categoryMap[category] || category;
# }
# ```

# %% [markdown]
# ### 手順3: data/blogs.json で新しいカテゴリを使用
#
# ブログ記事に新しいカテゴリを設定できます。
#
# ```json
# {
#   "id": 14,
#   "category": "data-science",
#   "platform": "qiita",
#   "date": "2025.10.15",
#   "image": "assets/images/blogs/data-science-intro.webp",
#   "title": "データサイエンス入門",
#   "titleEn": "Introduction to Data Science",
#   "description": "データサイエンスの基礎から実践まで解説します。",
#   "descriptionEn": "Explaining data science from basics to practice.",
#   "url": "https://qiita.com/tk256ailab/items/abc123"
# }
# ```

# %% [markdown]
# ### ブログカテゴリ追加のまとめ
#
# 新しいカテゴリ「data-science」を追加する場合:
#
# 1. ✅ `pages/blogs.html` にフィルターボタンを追加
# 2. ✅ `assets/js/filters.js` の `getCategoryNameJP()` に追加
# 3. ✅ `assets/js/filters.js` の `getCategoryNameEN()` に追加
# 4. ✅ `data/blogs.json` で新しいカテゴリを使用
#
# ### カテゴリIDの命名規則
#
# ✅ **推奨**:
# - 小文字とハイフン: `data-science`, `self-developed`
# - 短く簡潔: `ai`, `web`, `ml`
#
# ❌ **非推奨**:
# - スペース: `data science` (動作しません)
# - 大文字: `DataScience`
# - アンダースコア: `data_science`

# %% [markdown]
# ## タグの色のカスタマイズ
#
# プロジェクトタグに色を付けることができます。
#
# ### 手順1: assets/js/filters.js のタグカラーマップに追加
#
# `ProjectFilter` クラスの `applyTagColors()` メソッド内のカラーマップを編集します。

# %% [markdown]
# #### 編集箇所: assets/js/filters.js (ProjectFilter クラス)
#
# **現在のタグカラーマップ**:
#
# ```javascript
# applyTagColors() {
#     const tagColorMap = {
#         'python': 'tag-python',
#         'javascript': 'tag-javascript',
#         'react': 'tag-react',
#         'node.js': 'tag-nodejs',
#         'three.js': 'tag-threejs',
#         'webgl': 'tag-webgl',
#         'vrm': 'tag-vrm',
#         'animation': 'tag-animation',
#         'machine learning': 'tag-ml',
#         'data science': 'tag-datascience',
#         'kaggle': 'tag-kaggle',
#         'openai api': 'tag-openai',
#         'fastapi': 'tag-fastapi',
#         'ai': 'tag-ai'
#     };
#
#     // タグに色を適用
#     ...
# }
# ```

# %% [markdown]
# **新しいタグの色を追加**:
#
# ```javascript
# applyTagColors() {
#     const tagColorMap = {
#         'python': 'tag-python',
#         'javascript': 'tag-javascript',
#         'typescript': 'tag-typescript',  // 追加
#         'react': 'tag-react',
#         'react native': 'tag-react-native',  // 追加
#         'node.js': 'tag-nodejs',
#         'three.js': 'tag-threejs',
#         'webgl': 'tag-webgl',
#         'vrm': 'tag-vrm',
#         'animation': 'tag-animation',
#         'machine learning': 'tag-ml',
#         'data science': 'tag-datascience',
#         'kaggle': 'tag-kaggle',
#         'openai api': 'tag-openai',
#         'fastapi': 'tag-fastapi',
#         'firebase': 'tag-firebase',  // 追加
#         'ai': 'tag-ai'
#     };
#
#     // タグに色を適用
#     ...
# }
# ```
#
# **注意**: キーは小文字で記述します（自動的に小文字に変換されるため）。

# %% [markdown]
# ### 手順2: assets/css/components.css にスタイルを追加
#
# CSSファイルにタグの色を定義します。

# %% [markdown]
# #### 編集箇所: assets/css/components.css
#
# ファイルの末尾に追加します：
#
# ```css
# /* Project Tag Colors */
# .project-tag.tag-typescript {
#     background: linear-gradient(135deg, #3178c6 0%, #235a97 100%);
#     color: white;
# }
#
# .project-tag.tag-react-native {
#     background: linear-gradient(135deg, #61dafb 0%, #4fa8c5 100%);
#     color: #20232a;
# }
#
# .project-tag.tag-firebase {
#     background: linear-gradient(135deg, #ffca28 0%, #ffa000 100%);
#     color: #fff;
# }
# ```

# %% [markdown]
# ### 色の選び方
#
# | 技術 | 推奨カラー | 理由 |
# |------|-----------|------|
# | **TypeScript** | `#3178c6` (青) | 公式ロゴカラー |
# | **React Native** | `#61dafb` (水色) | Reactカラー |
# | **Firebase** | `#ffca28` (黄) | 公式カラー |
# | **Vue.js** | `#42b883` (緑) | 公式カラー |
# | **Go** | `#00add8` (シアン) | 公式カラー |
# | **Rust** | `#ce422b` (オレンジ) | 公式カラー |
# | **Docker** | `#2496ed` (青) | 公式カラー |
#
# ### グラデーションの作成
#
# ```css
# /* 基本パターン */
# background: linear-gradient(135deg, [明るい色] 0%, [暗い色] 100%);
#
# /* 例: TypeScript */
# background: linear-gradient(135deg, #3178c6 0%, #235a97 100%);
# ```
#
# **ツール**: [UIGradients](https://uigradients.com/) でグラデーションを生成できます。

# %% [markdown]
# ### 既存のタグカラー一覧
#
# 現在定義されているタグの色:
#
# ```css
# /* Python */
# .project-tag.tag-python {
#     background: linear-gradient(135deg, #3776ab 0%, #ffd343 100%);
#     color: white;
# }
#
# /* JavaScript */
# .project-tag.tag-javascript {
#     background: linear-gradient(135deg, #f7df1e 0%, #e6c300 100%);
#     color: #000;
# }
#
# /* React */
# .project-tag.tag-react {
#     background: linear-gradient(135deg, #61dafb 0%, #4fa8c5 100%);
#     color: #20232a;
# }
#
# /* Node.js */
# .project-tag.tag-nodejs {
#     background: linear-gradient(135deg, #68a063 0%, #3c6e3c 100%);
#     color: white;
# }
#
# /* Three.js */
# .project-tag.tag-threejs {
#     background: linear-gradient(135deg, #049ef4 0%, #026bb8 100%);
#     color: white;
# }
#
# /* その他のタグ... */
# ```

# %% [markdown]
# ## 動作確認
#
# ### タグ追加後の確認手順
#
# 1. **ローカルサーバーを起動**

# %%
python3 -m http.server 8000

# %% [markdown]
# 2. **ブラウザで確認**
#
#    - **プロジェクトページ**: http://localhost:8000/pages/projects.html
#    - **ブログページ**: http://localhost:8000/pages/blogs.html
#
# 3. **確認項目**
#
#    ✅ **プロジェクトタグ**
#    - 新しいタグのフィルターボタンが表示されているか
#    - タグをクリックしてフィルタリングが動作するか
#    - タグの色が正しく適用されているか
#
#    ✅ **ブログカテゴリ**
#    - 新しいカテゴリのボタンが表示されているか
#    - カテゴリをクリックしてフィルタリングが動作するか
#    - 言語切り替えで日本語/英語が正しく表示されるか

# %% [markdown]
# ### よくある問題
#
# | 問題 | 原因 | 解決方法 |
# |------|------|----------|
# | タグが表示されない | JSONファイルに記述していない | `data/projects.json` の `tags` フィールドを確認 |
# | タグの色が適用されない | CSSクラス名が間違っている | `tagColorMap` のキーとCSSセレクタを確認 |
# | カテゴリボタンが動作しない | `data-category` 属性が間違っている | HTMLとJavaScriptのカテゴリIDを確認 |
# | カテゴリ名が表示されない | カテゴリマップに追加していない | `getCategoryNameJP/EN()` を確認 |

# %% [markdown]
# ## まとめ
#
# ### プロジェクトタグの追加（簡単）
#
# 1. `data/projects.json` の `tags` フィールドに追加
# 2. （オプション）`assets/js/filters.js` のタグカラーマップに追加
# 3. （オプション）`assets/css/components.css` に色のスタイルを追加
#
# → **自動生成されるので簡単！**
#
# ### ブログカテゴリの追加（要編集）
#
# 1. `pages/blogs.html` にフィルターボタンを追加
# 2. `assets/js/filters.js` の `getCategoryNameJP()` に追加
# 3. `assets/js/filters.js` の `getCategoryNameEN()` に追加
# 4. `data/blogs.json` で新しいカテゴリを使用
#
# → **固定カテゴリのため複数ファイルの編集が必要**
#
# ### 編集ファイル一覧
#
# **プロジェクトタグ**:
# - `data/projects.json` （必須）
# - `assets/js/filters.js` （色を付ける場合）
# - `assets/css/components.css` （色を付ける場合）
#
# **ブログカテゴリ**:
# - `pages/blogs.html` （必須）
# - `assets/js/filters.js` （必須）
# - `data/blogs.json` （必須）
#
# ---
#
# **作成日**: 2025年10月
#
# **バージョン**: 1.0
#
# タグやカテゴリのカスタマイズで不明点があれば、このノートブックを参照してください！
